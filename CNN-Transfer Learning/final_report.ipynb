# %% [markdown]
# #Στοιχεία ομάδας
#
#
# ###Αριθμός ομάδας: 43
# Datasets: S05, B05
#
# ###Μέλη:
# Επίθετο | Όνομα | Α.Μ.
# ---|---|---
# Κορακοβούνης|Δημήτριος|03116692
# Αναγνωστόπουλος|Θεόδωρος|03116066
#
# <br>
# </br>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import joblib

# %%
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive/Neural 3h/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def summarize_diagnostics(history, duration = 0):
	plt.figure(figsize=(8, 8))
	plt.suptitle('Training Curves')
	# plot loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history['loss'], color='blue', label='train')
	plt.plot(history['val_loss'], color='orange', label='val')
	plt.legend(loc='upper right')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history['accuracy'], color='blue', label='train')
	plt.plot(history['val_accuracy'], color='orange', label='val')
	plt.legend(loc='lower right')
	return plt

# %%
def model_report_20(model, sub_path):
  [history, duration] = joblib.load(path+sub_path+model+".pkl")
  plt = summarize_diagnostics(history)
  print("Training Time: ", duration, "\n\n")
  plt.plot()

# %% [markdown]
# #20 Classes
#
# Αποτελέσματα των training για τα μοντέλα στο task των 20 κλάσεων

# %%
path = "/content/drive/My Drive/Neural 3h/20_classes/"

# %% [markdown]
# ##Batch size = 128

# %% [markdown]
# ###Model 1

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_1", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  17.357882976531982

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_1", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  11.237076997756958

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_1", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  16.209351539611816

# %% [markdown]
# ###Model 2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_2", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  15.645081758499146

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_2", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  10.567362546920776

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_2", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  11.664422035217285

# %% [markdown]
# ###Model 3

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_3", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  25.817588090896606

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_3", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  21.484880685806274

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_3", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  28.149590730667114

# %% [markdown]
# ###DenseNet

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("DenseNet 201", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  168.05234694480896

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("DenseNet 201", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  163.29278659820557

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("DenseNet 201", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  161.16026258468628

# %% [markdown]
# ###Inception-ResNet V2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Inception-ResNet V2", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  406.35775876045227

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Inception-ResNet V2", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  390.003431558609

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Inception-ResNet V2", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  408.92837357521057

# %% [markdown]
# ###Inception V3

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Inception V3", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  212.76833581924438

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Inception V3", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  185.78425884246826

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Inception V3", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  167.90357875823975

# %% [markdown]
# ###MobileNet v2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("MobileNet v2", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  43.17399978637695

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("MobileNet v2", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  39.98943471908569

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("MobileNet v2", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  55.52146053314209

# %% [markdown]
# ###ResNet v2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("ResNet v2", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  253.64206218719482

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("ResNet v2", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  247.8086450099945

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("ResNet v2", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  314.5324401855469

# %% [markdown]
# ###VGG16

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("VGG16", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  96.68769216537476

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("VGG16", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  92.67740654945374

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("VGG16", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  63.905232667922974

# %% [markdown]
# ###VGG19

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("VGG19", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  116.69378805160522

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("VGG19", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  112.91385054588318

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("VGG19", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  82.5684769153595

# %% [markdown]
# ###Xception

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Xception", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  505.14683866500854

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Xception", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  492.06133103370667

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Xception", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  347.1178960800171

# %% [markdown]
# ##Batch size = 512

# %% [markdown]
# ###Model 1

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_1", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  43.73284196853638

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_1", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  804.3415219783783

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_1", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  21.333775281906128

# %% [markdown]
# ###Model 2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_2", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  35.044248819351196

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_2", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  528.6163909435272

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_2", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  18.581456899642944

# %% [markdown]
# ###Model 3

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_3", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  69.32558679580688

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_3", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  2403.1689016819

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_3", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  47.53779411315918

# %% [markdown]
# ###DenseNet

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("DenseNet 201", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  409.0164453983307

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("DenseNet 201", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  240.09844541549683

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("DenseNet 201", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  272.3862946033478

# %% [markdown]
# ###Inception-ResNet V2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Inception-ResNet V2", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  1226.7360789775848

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Inception-ResNet V2", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  694.9722890853882

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Inception-ResNet V2", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  643.3154180049896

# %% [markdown]
# ###Inception V3

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Inception V3", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  610.3371419906616

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Inception V3", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  329.01114773750305

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Inception V3", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  363.942830324173

# %% [markdown]
# ###MobileNet v2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("MobileNet v2", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  110.61821150779724

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("MobileNet v2", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  60.74621844291687

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("MobileNet v2", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  80.54824018478394

# %% [markdown]
# ###ResNet v2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("ResNet v2", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  625.562525510788

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("ResNet v2", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  358.77853655815125

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("ResNet v2", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  496.10443234443665

# %% [markdown]
# ###VGG16

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("VGG16", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  274.554979801178

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("VGG16", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  152.6582751274109

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("VGG16", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  152.6582751274109

# %% [markdown]
# ###VGG19

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("VGG19", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  326.566143989563

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("VGG19", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  180.8383526802063

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("VGG19", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  137.76185202598572

# %% [markdown]
# ###Xception

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Xception", "512/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  1937.842279434204

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Xception", "512/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  1123.534662246704

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Xception", "512/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  1088.8543617725372

# %% [markdown]
# #80 Classes

# %%
path = "/content/drive/My Drive/Neural 3h/80_classes/"

# %% [markdown]
# ###Model 1

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_1", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  30.108410596847534

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_1", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  15.993115663528442

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_1", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  17.614532947540283

# %% [markdown]
# ###Model 2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_2", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  23.205267906188965

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_2", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  15.120932579040527

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_2", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  14.93118667602539

# %% [markdown]
# ###Model 3

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("model_3", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  33.200377464294434

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("model_3", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  26.24866271018982

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("model_3", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  19.808991193771362

# %% [markdown]
# ###DenseNet

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("DenseNet 201", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  176.8087341785431

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("DenseNet 201", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  165.97245144844055

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("DenseNet 201", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  223.7431457042694

# %% [markdown]
# ###Inception-ResNet V2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Inception-ResNet V2", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  563.1049425601959

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Inception-ResNet V2", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  400.6844115257263

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Inception-ResNet V2", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  549.2650058269501

# %% [markdown]
# ###Inception V3

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Inception V3", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  381.4331376552582

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Inception V3", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  192.89200043678284

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Inception V3", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  272.21182107925415

# %% [markdown]
# ###MobileNet v2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("MobileNet v2", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  51.2467474937439

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("MobileNet v2", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  42.82835364341736

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("MobileNet v2", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  58.24046802520752

# %% [markdown]
# ###ResNet v2

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("ResNet v2", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  256.0483703613281

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("ResNet v2", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  247.48677778244019

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("ResNet v2", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  122.04177856445312

# %% [markdown]
# ###VGG16

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("VGG16", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  101.7903938293457

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("VGG16", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  91.98263764381409

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("VGG16", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  128.7962248325348

# %% [markdown]
# ###VGG19

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("VGG19", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  124.0711452960968

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("VGG19", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  110.89042234420776

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("VGG19", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  120.54186058044434

# %% [markdown]
# ###Xception

# %%
print("\n####################################   UNOPTIMIZED   ####################################\n\n")

model_report_20("Xception", "128/unoptimized/")
# Out:
# ####################################   UNOPTIMIZED   ####################################
#
#
# Training Time:  594.0778136253357

# %%
print("\n####################################   HARDWARE OPTIMIZATION   ####################################\n\n")

model_report_20("Xception", "128/hardware_opt/")
# Out:
# ####################################   HARDWARE OPTIMIZATION   ####################################
#
#
# Training Time:  484.016633272171

# %%
print("\n####################################   MODEL OPTIMIZATION   ####################################\n\n")

model_report_20("Xception", "128/model_optimizations/")
# Out:
# ####################################   MODEL OPTIMIZATION   ####################################
#
#
# Training Time:  676.423748254776
